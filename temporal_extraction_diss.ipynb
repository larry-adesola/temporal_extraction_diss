# %% [markdown]
# <a href="https://colab.research.google.com/github/larry-adesola/temporal_extraction_diss/blob/main/temporal_extraction_diss.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hi")
# Out:
# hi
